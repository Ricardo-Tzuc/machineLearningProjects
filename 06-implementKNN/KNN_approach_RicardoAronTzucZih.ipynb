# %% [markdown]
# #KNN Algorithm

# %% [markdown]
# 1. Intuition of KNN
#  - KNN comes from K Nearest Neightbort, what it means that the data point that we are observating will get K-numbers of the nearest data points to find the best approach to a group in specific to be labeled according to the majority vote given by the observated groups; this, in case we are applying the algorithm to a classificator model.

# %% [markdown]
# 2. Pseudocode

# %% [markdown]
# ```
# def of KNN(k): #recieves k values
#   k = 3 # as default parameter
# def fit( X, y): #split vectors of training data.
#
# def predict(X): #recieves a vector to be determined.
#   predictions = [_predict(x) for x in X] #calls the method _predict() based on the vector given.
#
# def _predict(x): #recieve the observation
#   distances = [euclidean_distance(x, x_train) for x_train in self.X_train]
#   #It uses vector given and training vector to create a distance vector of each observation by using Euclidean formula.
#
#   k_indices = np.argsort(distances)[:k] #the function sorts the distances and keeps the k observations.
#
#   k_nearest_labels = [y_train[i] for i in k_indices] #get the labels' of K_indices
#
#   most_common = Counter(k_nearest_labels).most_common() #Counts the quantity of recurrence in each group.
#
#   most_common[0][0] #return the common one from the array.
#
# ```

# %%
#First we initialize the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
def euclidean_distance(x1, x2):
    distance = np.sqrt(np.sum((x1-x2)**2))
    return distance

class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = [self._predict(x) for x in X]
        return predictions

    def _predict(self, x):
        # compute the distance
        distances = [euclidean_distance(x, x_train) for x_train in self.X_train]

        # get the closest k
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]

        # majority voye
        most_common = Counter(k_nearest_labels).most_common()
        return most_common[0][0]

# %% [markdown]
# Data frame of kilometers made by a car, saying that the average is 15km per year, we evaluate if a car is worthy to be bought depending in its kilomer taking into acount till 2022

# %%
#15km per year till 2022
dataframe = np.array([
    ["year","km", "buy"],
    [2015, 107, 1],
    [2006, 240, 1],
    [2005, 330, 0],
    [2006, 220, 1],
    [2012, 220, 0],
    [2001, 550, 0],
    [2001, 316, 1],
    [2003, 289, 1],
    [2007, 228, 1],
    [2019, 110, 0],
    [2010, 182, 1],
    [2004, 315, 0],
    [2000, 390, 0],
    [2014, 125, 1],
    [2011, 190, 0],
    [2016, 150, 0],
    [2017, 150, 0],
    [2009, 255, 0],
    ])
# Spliting the data to have X vector and y vector
X = dataframe[1:, :2].astype(int)
y = dataframe[1:, 2].astype(int)

# Initialize the KNN classifier with the value K wanted
knn = KNN(k=5)

# Fit the KNN classifier with the data
knn.fit(X, y)

# Define the input data point to be test
input_data = np.array([2001, 390])

# Make a prediction for the input data point
prediction = knn.predict([input_data])

# Extract data for plotting
years = X[:, 0]
kilometers = X[:, 1]
buy = y

# Create a scatter plot of the data points
plt.scatter(years[buy == 1], kilometers[buy == 1], color='green', label='Buy')
plt.scatter(years[buy == 0], kilometers[buy == 0], color='red', label='Do Not Buy')
plt.scatter(input_data[0], input_data[1], color='blue', marker='x', label='Input Data')

# Set plot labels
plt.xlabel('Year')
plt.ylabel('Kilometers')
plt.title('Car Buying Decision')
plt.legend()
print(prediction)
# Show the predicted group for the input data
if prediction[0] == 1:
    print("The input data is predicted to belong to the 'Buy' group.")
else:
    print("The input data is predicted to belong to the 'Do Not Buy' group.")

# Show the plot
plt.show()
# Out:
# [0]
# The input data is predicted to belong to the 'Do Not Buy' group.

# %% [markdown]
# **IMPORTANT** \\
# The loss function and a optimization function are not necesary for this algorithm, they are not typically used in KNN, as KNN is a non-parametric algorithm and doesn't involve a training step with optimization.
